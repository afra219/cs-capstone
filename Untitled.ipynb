# %%
import pandas as pd
import os
#import requests
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import linear_model,metrics, model_selection, svm

csv_input = open('banknote_authentication.csv')
names = ['Variance Of Wavelet', 'Skewness of Wavelet', 'Curtosis of Wavelet', 'Entropy', 'Classification']
df = pd.read_csv(csv_input, names=names)

myLogModel = linear_model.LogisticRegression(max_iter=1000)
svm_model = svm.SVC(max_iter=1000)
y = df.values[:, 4]
X = df.values[:, 0:4]

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y,test_size=0.3)

myLogModel.fit(X_train,y_train)
svm_model.fit(X_train,y_train)

y_pred_true = myLogModel.predict(X)
y_pred = myLogModel.predict(X_test)
y_pred_svm = svm_model.predict(X_test)

#print( metrics.accuracy_score(y_test,y_pred) )
#print( metrics.accuracy_score(y_test,y_pred_svm) )

#metrics.plot_confusion_matrix(svm_model,X_test,y_test)
disp = ConfusionMatrixDisplay.from_predictions(y_true=y, y_pred=y_pred_true)

# %%
csv_input = open('banknote_authentication.csv')
names = ['Variance', 'Skewness', 'Curtosis', 'Entropy', 'Classification']
df = pd.read_csv(csv_input, names=names)

#print(df)

myLogModel = linear_model.LogisticRegression(max_iter=1000)
svm_model = svm.SVC(max_iter=1000)
y = df.values[:, 4]
X = df.values[:, 0:4]

#print("Dif")
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y,test_size=0.3)

myLogModel.fit(X_train,y_train)
#print(y_pred)

plt.scatter(X[:,0],X[:,3], c=y)
plt.xlabel("Variance")
plt.ylabel("Entropy")
plt.show()

# %%
a = input();
b = a.split(",")
c = []

for item in b:
    c.append(float(item))

#print(c)
d = []
d.append(c)
print("Raw===>" + a)
print("Sanatized===>", d)
csv_input = open('banknote_authentication.csv')
names = ['Variance', 'Skewness', 'Curtosis', 'Entropy', 'Classification']
df = pd.read_csv(csv_input, names=names)

#print(df)

myLogModel = linear_model.LogisticRegression(max_iter=1000)
svm_model = svm.SVC(max_iter=1000)
y = df.values[:, 4]
X = df.values[:, 0:4]

#print("Dif")
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y,test_size=0.3)

myLogModel.fit(X_train,y_train)
#print(y_pred)
pred = myLogModel.predict(d)
retPred = ""
if pred == 0:
    retPred = "Authentic"
else:
    rePred = "Inauthentic"
    
print("Prediction===>",retPred)
# Out:
#  1,2,3,4
# Raw===>1,2,3,4
# Sanatized===> [[1.0, 2.0, 3.0, 4.0]]
# Prediction===> Authentic
